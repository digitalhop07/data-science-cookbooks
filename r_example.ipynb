# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Import-Libraries-for-R" data-toc-modified-id="Import-Libraries-for-R-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Import Libraries for R</a></span></li><li><span><a href="#Plot-some-Data-with-ggplot2" data-toc-modified-id="Plot-some-Data-with-ggplot2-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Plot some Data with ggplot2</a></span></li></ul></div>

# %% [markdown]
# # Import Libraries for R

# %%
library(ggplot2)

# %% [markdown]
# # Plot some Data with ggplot2

# %%
qplot(wt, mpg, data=mtcars, geom=c('point', 'smooth'),
     method='lm', formula=y~x, color=cyl,
     main='Regression of MPG on Weight',
     xlab='Weight', ylab='Miles per Gallon')
# Out:
# Warning message:
# "Ignoring unknown parameters: method, formula"
# plot without title

# %% [markdown]
# ![Image of Yaktocat](https://media2.giphy.com/media/nL3RKyczC6092/giphy.gif)
